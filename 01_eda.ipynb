# %%
import pandas as pd
import json

from util import parse_match_to_dataframe

filepath = "./data/world_cup_2026/match_1953853_Mexico_vs_South_Africa.json"

df = parse_match_to_dataframe(filepath)

print(df.head())
# Out:
#                event_id  team_id  ... starting_state finishing_state
# match_seconds                     ...
# 0.0                   2      972  ...     Z:2_P:Home      Z:1_P:Home
# 2.0                   3      972  ...     Z:1_P:Home      Z:1_P:Home
# 7.0                   4      972  ...     Z:1_P:Home      Z:1_P:Home
# 10.0                  5      972  ...     Z:1_P:Home      Z:1_P:Home
# 13.0                  6      972  ...     Z:1_P:Home      Z:1_P:Home
#
# [5 rows x 6 columns]
