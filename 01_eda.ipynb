# %%
import pandas as pd

from util import parse_match_to_dataframe

filepath = "./data/world_cup_2026/match_1953865_USA_vs_Paraguay.json"

df = parse_match_to_dataframe(filepath)

print(df[df["finishing_state"] == "Goal_H"])
print("--------------------")
print(df[df["finishing_state"] == "Goal_A"])
# Out:
#                event_id  team_id                                  type  \
# match_seconds
# 408.0                62      417  {'value': 16, 'displayName': 'Goal'}
# 1819.0              301      461  {'value': 16, 'displayName': 'Goal'}
# 2942.0              549      461  {'value': 16, 'displayName': 'Goal'}
# 6201.0             1032      461  {'value': 16, 'displayName': 'Goal'}
#
#                                             outcome_type starting_state  \
# match_seconds
# 408.0          {'value': 1, 'displayName': 'Successful'}     Z:0_P:Away
# 1819.0         {'value': 1, 'displayName': 'Successful'}     Z:4_P:Home
# 2942.0         {'value': 1, 'displayName': 'Successful'}     Z:4_P:Home
# 6201.0         {'value': 1, 'displayName': 'Successful'}     Z:4_P:Home
#
#               finishing_state  time_spent_seconds
# match_seconds
# 408.0                  Goal_H                 3.0
# 1819.0                 Goal_H                 3.0
# ...
